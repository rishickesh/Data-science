# %% [markdown]
# <img src="http://www.digitalvidya.com/wp-content/uploads/2013/05/logoa5-300x95.png">

# %% [markdown]
# ## Data Analysis using Python Assignment
# ### Digital Vidya Copyright

# %% [markdown]
# Load the ipl datasets deliveries.csv and matches.csv into a pandas dataframe and answer the quesions based on these dataset.

# %%
import pandas as pd
import numpy as np
deliveries = pd.read_csv('deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
matches = pd.read_csv('matches.csv')
matches.head()
matches.columns=['match_id','season','city','date','team1','team2','toss_winner','toss_decision','result','dl_applied','winner','win_by_runs','win_by_wickets','player_of_match','venue','umpire1','umpire2','umpire3']
matches
# Out:
#      match_id  season           city        date                        team1  \
# 0           1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1           2    2017           Pune  2017-04-06               Mumbai Indians
# 2           3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3           4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4           5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5           6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6           7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7           8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8           9    2017           Pune  2017-04-11             Delhi Daredevils
# 9          10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10         11    2017        Kolkata  2017-04-13              Kings XI Punjab
# ...

# %%
#1. Merge both the datasets so that the resulting df would have all the columns. Call it ipl_total. 
# The shape would be (136598, 39)
ipl_total=pd.concat([deliveries,matches],axis=1)
ipl_total.isnull().any()
ipl_total
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
#2. The dataset deliveries has the ball-by-ball summary of each match from 2008 to 2016 but it doesn't have season 
# column making it difficult to segregate the data season-wise. Merge both the datasets such that the dataset 
# deliveries also gets an additional column season and store it in deliveries_season. Drop the duplicate column id. 
# The shape deliveries_season should be (136598, 22). 
deliveries_season=pd.merge(deliveries,matches[['season','match_id']],on='match_id')
deliveries_season
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
#3. Use groupby on the dataset matches to return only the winner for each season (each rwo representing winner for 
# each season starting from 2008). Store it in a new dataframe called winners. 
#Hint: the last match of each seaon would be the final of that season. The shape of winners should be (9,17)
winners = matches.groupby('season').last()
#winners.shape
winners
# Out:
#         match_id          city        date                team1  \
# season
# 2008         117        Mumbai  2008-06-01  Chennai Super Kings
# 2009         174  Johannesburg  2009-05-24      Deccan Chargers
# 2010         234        Mumbai  2010-04-25  Chennai Super Kings
# 2011         307       Chennai  2011-05-28  Chennai Super Kings
# 2012         381       Chennai  2012-05-27  Chennai Super Kings
# 2013         457       Kolkata  2013-05-26       Mumbai Indians
# 2014         517     Bangalore  2014-06-01      Kings XI Punjab
# 2015         576       Kolkata  2015-05-24       Mumbai Indians
# 2016         636     Bangalore  2016-05-29  Sunrisers Hyderabad
# 2017          59     Hyderabad  2017-05-21       Mumbai Indians
#
#                               team2                  toss_winner  \
# season
# 2008               Rajasthan Royals             Rajasthan Royals
# 2009    Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
#4. Use the deliveries_season df created in qn 2 to find the total runs scored by each team per season. Store the 
#resulting dataframe as season_run_summary. The shape would be (76, 3)
season_run_summary=deliveries_season.groupby(['season','batting_team'])['total_runs'].sum()
season_run_summary
# Out:
# season  batting_team
# 2008    Chennai Super Kings            2520
#         Deccan Chargers                2229
#         Delhi Daredevils               2118
#         Kings XI Punjab                2464
#         Kolkata Knight Riders          1942
#         Mumbai Indians                 2080
#         Rajasthan Royals               2601
#         Royal Challengers Bangalore    1983
# 2009    Chennai Super Kings            2231
#         Deccan Chargers                2408
#         Delhi Daredevils               2131
#         Kings XI Punjab                1928
#         Kolkata Knight Riders          1772
#         Mumbai Indians                 1897
#         Rajasthan Royals               1706
#         Royal Challengers Bangalore    2280
# 2010    Chennai Super Kings            2604
#         Deccan Chargers                2374
#         Delhi Daredevils               2155
#         Kings XI Punjab                2288
#         Kolkata Knight Riders          2144
# ...

# %%
#5. Use the deliveries_season df created in qn 2 to find the total wickets taken by each bowler per seaon per team.
# Store it in season_wicket_summary, shape should be (1036, 4)
season_wicket_summary=deliveries_season.groupby(['season','bowling_team','bowler']).player_dismissed.count()
season_wicket_summary
# Out:
# season  bowling_team                 bowler
# 2008    Chennai Super Kings          CK Kapugedera         0
#                                      JA Morkel            20
#                                      JDP Oram              6
#                                      Joginder Sharma       9
#                                      L Balaji             11
#                                      M Muralitharan       11
#                                      M Ntini               8
#                                      MS Gony              18
#                                      P Amarnath            7
#                                      S Vidyut              1
#                                      SK Raina              2
#         Deccan Chargers              A Symonds             0
#                                      D Kalyankrishna       2
#                                      DB Ravi Teja          1
#                                      DNT Zoysa             2
# ...

# %%
#6. Consider the following dataframe. Reshape it such that it contains three columns: time, part (part_0_hits or 
# part_1_hits) and hits (values corresponding to the part_0_hits and part_1_hits). Store it in part_df_melted
 #multicol1 = pd.MultiIndex.from_tuples([('weight', 'kg'), ('weight', 'pounds')])
d = {'time':[0,1,2], 'part_0_hits': [100,200,300], 'part_1_hits': [25,50,75]}
part_df = pd.DataFrame(d)
#part_df.stack()
part_df.set_index('time').stack().reset_index()
#part_df = pd.melt(part_df, id_vars=["time"],var_name="part")
#part_df
# Out:
#    time      level_1    0
# 0     0  part_0_hits  100
# 1     0  part_1_hits   25
# 2     1  part_0_hits  200
# 3     1  part_1_hits   50
# 4     2  part_0_hits  300
# 5     2  part_1_hits   75

# %%
#7. Use the part_df_melted generated in qn 6 and change the part column to show only the corresponding part numbers 
# (0 or 1 inplace of part_0_hits or part_1_hits)
part_df = pd.melt(part_df, id_vars=["time"],var_name="part")
part_df['part'] = part_df['part'].str.extract('(\d+)', expand = False)
part_df
# Out:
#    time part  value
# 0     0    0    100
# 1     1    0    200
# 2     2    0    300
# 3     0    1     25
# 4     1    1     50
# 5     2    1     75

# %%
#8. Pivot the following dataframe to create 5 columns: labels, A,B,C,D. 
data = {"grouping": ["item1", "item1", "item1", "item2", "item2", "item2", "item2"],
        "labels": ["A", "B", "C", "A", "B", "C", "D"],
        "count": [5, 1, 8, 3, 731, 189, 9]}
df = pd.DataFrame(data)
ne=df.pivot(index='grouping',columns='labels',values='count')
ne
# Out:
# labels      A      B      C    D
# grouping
# item1     5.0    1.0    8.0  NaN
# item2     3.0  731.0  189.0  9.0

# %%
#9. Pivot the following dataframe to create df_pivoted with four columns: category, A, B, C. Aggregate the values on sum.
df = pd.DataFrame({'Name' : ['one', 'one', 'two', 'three'] * 3,
                   'Category' : ['A', 'B', 'C'] * 4,
               'Value' : range(12)})
#df.pivot(columns='Category',values='Value')
df = pd.pivot_table(df, index='Name', columns='Category', values = 'Value', aggfunc='first')
df
# Out:
# Category  A   B   C
# Name
# one       0   1   5
# three     3   7  11
# two       6  10   2

# %%
#10. Use the df_pivoted generated in qn 9 and add three columns A_pct, B_pct, C_pct to represent the percentage 
# values of each cell per column. Hint: use df.apply(lambda x: .....)

# %%
df['A_pct']=df['A'].apply(lambda x: x/df.sum()).sum(axis=1)

df['B_pct']=df['B'].apply(lambda x: x/df.sum()).sum(axis=1)
df['C_pct']=df['C'].apply(lambda x: x/df.sum()).sum(axis=1)

# %%
df
# Out:
# Category  A   B   C     A_pct     B_pct     C_pct
# Name
# one       0   1   5  0.000000  0.722222  3.995726
# three     3   7  11  0.666667  5.055556  8.790598
# two       6  10   2  1.333333  7.222222  1.598291
